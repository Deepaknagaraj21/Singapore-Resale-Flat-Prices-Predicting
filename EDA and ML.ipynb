# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r'C:\Users\Ndeep\Desktop\combined.csv')
df
# Out:
#        latitude   longitude  blk_no    road_name  postal_code  \
# 0      1.307435  103.854714   640.0  ROWELL ROAD     200640.0
# 1      1.307435  103.854714   640.0  ROWELL ROAD     200640.0
# 2      1.307435  103.854714   640.0  ROWELL ROAD     200640.0
# 3      1.307435  103.854714   640.0  ROWELL ROAD     200640.0
# 4      1.307435  103.854714   640.0  ROWELL ROAD     200640.0
# ...         ...         ...     ...          ...          ...
# 41549  1.307435  103.854714   640.0  ROWELL ROAD     200640.0
# 41550  1.307435  103.854714   640.0  ROWELL ROAD     200640.0
# 41551  1.307435  103.854714   640.0  ROWELL ROAD     200640.0
# 41552  1.307435  103.854714   640.0  ROWELL ROAD     200640.0
# 41553  1.307435  103.854714   640.0  ROWELL ROAD     200640.0
#
#                     address     cbd_dist  min_dist_mrt    month        town  \
# 0      174 ANG MO KIO AVE 4  2728.531219           0.0  2015-01  ANG MO KIO
# 1      174 ANG MO KIO AVE 4  2728.531219           0.0  2015-12  ANG MO KIO
# 2      174 ANG MO KIO AVE 4  2728.531219           0.0  2016-05  ANG MO KIO
# 3      174 ANG MO KIO AVE 4  2728.531219           0.0  2016-06  ANG MO KIO
# 4      174 ANG MO KIO AVE 4  2728.531219           0.0  2016-11  ANG MO KIO
# ...                     ...          ...           ...      ...         ...
# 41549   223 PASIR RIS ST 21  2728.531219           0.0  2017-12   PASIR RIS
# 41550   223 PASIR RIS ST 21  2728.531219           0.0  2021-02   PASIR RIS
# 41551   223 PASIR RIS ST 21  2728.531219           0.0  2021-02   PASIR RIS
# 41552   223 PASIR RIS ST 21  2728.531219           0.0  2022-09   PASIR RIS
# 41553   223 PASIR RIS ST 21  2728.531219           0.0  2022-11   PASIR RIS
#
#        flat_type block       street_name storey_range  floor_area_sqm  \
# 0         3 ROOM   174  ANG MO KIO AVE 4     07 TO 09            60.0
# 1         3 ROOM   174  ANG MO KIO AVE 4     10 TO 12            60.0
# 2         3 ROOM   174  ANG MO KIO AVE 4     04 TO 06            69.0
# 3         2 ROOM   174  ANG MO KIO AVE 4     07 TO 09            45.0
# 4         3 ROOM   174  ANG MO KIO AVE 4     04 TO 06            61.0
# ...          ...   ...               ...          ...             ...
# 41549  EXECUTIVE   223   PASIR RIS ST 21     04 TO 06           149.0
# 41550  EXECUTIVE   223   PASIR RIS ST 21     04 TO 06           148.0
# 41551  EXECUTIVE   223   PASIR RIS ST 21     04 TO 06           147.0
# 41552  EXECUTIVE   223   PASIR RIS ST 21     07 TO 09           149.0
# 41553  EXECUTIVE   223   PASIR RIS ST 21     07 TO 09           147.0
#
#       flat_model  lease_commence_date  resale_price     remaining_lease  \
# 0       Improved                 1986      255000.0                70.0
# 1       Improved                 1986      275000.0                  69
# 2       Improved                 1986      310000.0                  68
# 3       Improved                 1986      253000.0                  68
# 4       Improved                 1986      290000.0                  68
# ...          ...                  ...           ...                 ...
# 41549  Apartment                 1993      635000.0  74 years 07 months
# 41550  Apartment                 1993      560000.0  71 years 06 months
# 41551  Apartment                 1993      590000.0  71 years 06 months
# 41552  Apartment                 1993      740000.0  69 years 11 months
# 41553  Apartment                 1993      830000.0  69 years 09 months
#
#        lease_remain_years
# 0                      62
# 1                      62
# 2                      62
# 3                      62
# 4                      62
# ...                   ...
# 41549                  69
# 41550                  69
# 41551                  69
# 41552                  69
# 41553                  69
#
# [41554 rows x 20 columns]

# %%
df.dtypes
# Out:
# latitude               float64
# longitude              float64
# blk_no                 float64
# road_name               object
# postal_code            float64
# address                 object
# cbd_dist               float64
# min_dist_mrt           float64
# month                   object
# town                    object
# flat_type               object
# block                   object
# street_name             object
# storey_range            object
# floor_area_sqm         float64
# flat_model              object
# lease_commence_date      int64
# resale_price           float64
# remaining_lease         object
# lease_remain_years       int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# latitude               0
# longitude              0
# blk_no                 0
# road_name              0
# postal_code            0
# address                0
# cbd_dist               0
# min_dist_mrt           0
# month                  0
# town                   0
# flat_type              0
# block                  0
# street_name            0
# storey_range           0
# floor_area_sqm         0
# flat_model             0
# lease_commence_date    0
# resale_price           0
# remaining_lease        0
# lease_remain_years     0
# dtype: int64

# %%
import statistics

def get_median(x):
    split_list = x.split(' TO ')
    float_list = [float(i) for i in split_list]
    median = statistics.median(float_list)
    return median

# %%
df['storey_median'] = df['storey_range'].apply(lambda x: get_median(x))
df
# Out:
#        latitude   longitude  blk_no    road_name  postal_code  \
# 0      1.307435  103.854714   640.0  ROWELL ROAD     200640.0
# 1      1.307435  103.854714   640.0  ROWELL ROAD     200640.0
# 2      1.307435  103.854714   640.0  ROWELL ROAD     200640.0
# 3      1.307435  103.854714   640.0  ROWELL ROAD     200640.0
# 4      1.307435  103.854714   640.0  ROWELL ROAD     200640.0
# ...         ...         ...     ...          ...          ...
# 41549  1.307435  103.854714   640.0  ROWELL ROAD     200640.0
# 41550  1.307435  103.854714   640.0  ROWELL ROAD     200640.0
# 41551  1.307435  103.854714   640.0  ROWELL ROAD     200640.0
# 41552  1.307435  103.854714   640.0  ROWELL ROAD     200640.0
# 41553  1.307435  103.854714   640.0  ROWELL ROAD     200640.0
#
#                     address     cbd_dist  min_dist_mrt    month        town  \
# 0      174 ANG MO KIO AVE 4  2728.531219           0.0  2015-01  ANG MO KIO
# 1      174 ANG MO KIO AVE 4  2728.531219           0.0  2015-12  ANG MO KIO
# 2      174 ANG MO KIO AVE 4  2728.531219           0.0  2016-05  ANG MO KIO
# 3      174 ANG MO KIO AVE 4  2728.531219           0.0  2016-06  ANG MO KIO
# 4      174 ANG MO KIO AVE 4  2728.531219           0.0  2016-11  ANG MO KIO
# ...                     ...          ...           ...      ...         ...
# 41549   223 PASIR RIS ST 21  2728.531219           0.0  2017-12   PASIR RIS
# 41550   223 PASIR RIS ST 21  2728.531219           0.0  2021-02   PASIR RIS
# 41551   223 PASIR RIS ST 21  2728.531219           0.0  2021-02   PASIR RIS
# 41552   223 PASIR RIS ST 21  2728.531219           0.0  2022-09   PASIR RIS
# 41553   223 PASIR RIS ST 21  2728.531219           0.0  2022-11   PASIR RIS
#
#        ... block       street_name storey_range floor_area_sqm  flat_model  \
# 0      ...   174  ANG MO KIO AVE 4     07 TO 09           60.0    Improved
# 1      ...   174  ANG MO KIO AVE 4     10 TO 12           60.0    Improved
# 2      ...   174  ANG MO KIO AVE 4     04 TO 06           69.0    Improved
# 3      ...   174  ANG MO KIO AVE 4     07 TO 09           45.0    Improved
# 4      ...   174  ANG MO KIO AVE 4     04 TO 06           61.0    Improved
# ...    ...   ...               ...          ...            ...         ...
# 41549  ...   223   PASIR RIS ST 21     04 TO 06          149.0   Apartment
# 41550  ...   223   PASIR RIS ST 21     04 TO 06          148.0   Apartment
# 41551  ...   223   PASIR RIS ST 21     04 TO 06          147.0   Apartment
# 41552  ...   223   PASIR RIS ST 21     07 TO 09          149.0   Apartment
# 41553  ...   223   PASIR RIS ST 21     07 TO 09          147.0   Apartment
#
#       lease_commence_date  resale_price     remaining_lease  \
# 0                    1986      255000.0                70.0
# 1                    1986      275000.0                  69
# 2                    1986      310000.0                  68
# 3                    1986      253000.0                  68
# 4                    1986      290000.0                  68
# ...                   ...           ...                 ...
# 41549                1993      635000.0  74 years 07 months
# 41550                1993      560000.0  71 years 06 months
# 41551                1993      590000.0  71 years 06 months
# 41552                1993      740000.0  69 years 11 months
# 41553                1993      830000.0  69 years 09 months
#
#       lease_remain_years  storey_median
# 0                     62            8.0
# 1                     62           11.0
# 2                     62            5.0
# 3                     62            8.0
# 4                     62            5.0
# ...                  ...            ...
# 41549                 69            5.0
# 41550                 69            5.0
# 41551                 69            5.0
# 41552                 69            8.0
# 41553                 69            8.0
#
# [41554 rows x 21 columns]

# %%
scope_df = df[['cbd_dist','min_dist_mrt','floor_area_sqm','lease_remain_years','storey_median','resale_price']]
scope_df
# Out:
#           cbd_dist  min_dist_mrt  floor_area_sqm  lease_remain_years  \
# 0      2728.531219           0.0            60.0                  62
# 1      2728.531219           0.0            60.0                  62
# 2      2728.531219           0.0            69.0                  62
# 3      2728.531219           0.0            45.0                  62
# 4      2728.531219           0.0            61.0                  62
# ...            ...           ...             ...                 ...
# 41549  2728.531219           0.0           149.0                  69
# 41550  2728.531219           0.0           148.0                  69
# 41551  2728.531219           0.0           147.0                  69
# 41552  2728.531219           0.0           149.0                  69
# 41553  2728.531219           0.0           147.0                  69
#
#        storey_median  resale_price
# 0                8.0      255000.0
# 1               11.0      275000.0
# 2                5.0      310000.0
# 3                8.0      253000.0
# 4                5.0      290000.0
# ...              ...           ...
# 41549            5.0      635000.0
# 41550            5.0      560000.0
# 41551            5.0      590000.0
# 41552            8.0      740000.0
# 41553            8.0      830000.0
#
# [41554 rows x 6 columns]

# %%
scope_df = scope_df.drop_duplicates()
scope_df
# Out:
#           cbd_dist  min_dist_mrt  floor_area_sqm  lease_remain_years  \
# 0      2728.531219           0.0            60.0                  62
# 1      2728.531219           0.0            60.0                  62
# 2      2728.531219           0.0            69.0                  62
# 3      2728.531219           0.0            45.0                  62
# 4      2728.531219           0.0            61.0                  62
# ...            ...           ...             ...                 ...
# 41548  2728.531219           0.0           147.0                  69
# 41549  2728.531219           0.0           149.0                  69
# 41550  2728.531219           0.0           148.0                  69
# 41552  2728.531219           0.0           149.0                  69
# 41553  2728.531219           0.0           147.0                  69
#
#        storey_median  resale_price
# 0                8.0      255000.0
# 1               11.0      275000.0
# 2                5.0      310000.0
# 3                8.0      253000.0
# 4                5.0      290000.0
# ...              ...           ...
# 41548            5.0      590000.0
# 41549            5.0      635000.0
# 41550            5.0      560000.0
# 41552            8.0      740000.0
# 41553            8.0      830000.0
#
# [35363 rows x 6 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
col = ['cbd_dist','min_dist_mrt','floor_area_sqm','lease_remain_years','storey_median','resale_price']

for i in col:
    plt.figure(figsize=(8, 6))  
    sns.boxplot(data=df, x=i)
    plt.title(f'Boxplot of {i}')
    plt.xlabel(i)
    plt.show()

# %%
df1 = scope_df

# %%
df1['floor_area_sqm'] = np.log(df1['floor_area_sqm'])
sns.boxplot(x='floor_area_sqm', data=df1)
plt.show()

df1['storey_median'] = np.log(df1['storey_median'])
sns.boxplot(x='storey_median', data=df1)
plt.show()

df1['resale_price'] = np.log(df1['resale_price'])
sns.boxplot(x='resale_price', data=df1)
plt.show()

# %%
df1.dtypes
# Out:
# cbd_dist              float64
# min_dist_mrt          float64
# floor_area_sqm        float64
# lease_remain_years      int64
# storey_median         float64
# resale_price          float64
# dtype: object

# %%
import seaborn as sns

# %%
corrMatrix = df1.corr()
plt.figure(figsize=(15, 10))
plt.title("Correlation Heatmap")
sns.heatmap(
    corrMatrix, 
    xticklabels=corrMatrix.columns,
    yticklabels=corrMatrix.columns,
    cmap='RdBu', 
    annot=True
)
# Out:
# <Axes: title={'center': 'Correlation Heatmap'}>

# %%
from sklearn.preprocessing import StandardScaler

X=df1[['cbd_dist','min_dist_mrt','floor_area_sqm','lease_remain_years','storey_median']]
y=df1['resale_price']

# Normalizing the encoded data
scaler = StandardScaler()
X = scaler.fit_transform(X)

# %%
test_dataframe = pd.DataFrame(X)
test_dataframe
# Out:
#                   0    1         2         3         4
# 0     -4.547474e-13  0.0 -1.634060 -0.362725  0.207690
# 1     -4.547474e-13  0.0 -1.634060 -0.362725  0.646828
# 2     -4.547474e-13  0.0 -1.096761 -0.362725 -0.440433
# 3     -4.547474e-13  0.0 -2.740020 -0.362725  0.207690
# 4     -4.547474e-13  0.0 -1.570515 -0.362725 -0.440433
# ...             ...  ...       ...       ...       ...
# 35358 -4.547474e-13  0.0  1.810847  0.267818 -0.440433
# 35359 -4.547474e-13  0.0  1.862799  0.267818 -0.440433
# 35360 -4.547474e-13  0.0  1.836910  0.267818 -0.440433
# 35361 -4.547474e-13  0.0  1.862799  0.267818  0.207690
# 35362 -4.547474e-13  0.0  1.810847  0.267818  0.207690
#
# [35363 rows x 5 columns]

# %%
from sklearn.model_selection import train_test_split

# test and train split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.model_selection import GridSearchCV

# Decision Tree Regressor
dtr = DecisionTreeRegressor()

# hyperparameters
param_grid = {
    'max_depth': [2, 5, 10, 15, 20, 22],
    'min_samples_split': [2, 3, 4, 5],
    'min_samples_leaf': [2, 3, 4, 5, 6, 7, 8, 9, 10, 15, 20],
    'max_features': ['auto', 'sqrt', 'log2']
}

# gridsearchcv
grid_search = GridSearchCV(estimator=dtr, param_grid=param_grid, cv=5)
grid_search.fit(X_train, y_train)
print("Best hyperparameters:", grid_search.best_params_)
best_model = grid_search.best_estimator_
y_pred = best_model.predict(X_test)

# evalution metrics
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)
print(" ")
print('Mean squared error:', mse)
print('Mean Absolute Error', mae)
print('Root Mean squared error:', rmse)
print(" ")
print('R-squared:', r2)
# Out:
# Best hyperparameters: {'max_depth': 15, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 5}
#
# Mean squared error: 0.029695769717645912
# Mean Absolute Error 0.13548413831147302
# Root Mean squared error: 0.17232460566513974
#
# R-squared: 0.7426609781474736

# %%
new_sample = np.array([[8740, 999, np.log(44), 55, np.log(11)]])
new_sample = scaler.transform(new_sample[:, :5])
new_pred = best_model.predict(new_sample)[0]
np.exp(new_pred)
# Out:
# 220454.0768504859

# %%
import pickle
with open('model.pkl', 'wb') as file:
    pickle.dump(best_model, file)
with open('scaler.pkl', 'wb') as f:
    pickle.dump(scaler, f)
